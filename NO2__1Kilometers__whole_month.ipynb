# %%
import pandas as pd
import dtale
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error,explained_variance_score
import glob
import dask.dataframe as dd
import xarray as xr
from scipy import stats

# %%
#Calculation for May 2018

df_May_2018= pd.read_csv('2018 May Grnd.csv')
df=df_May_2018

MEAN_NO2_may=df['MEAN_NO2'].values
NO2_satellite_may=df['NO2_satellite'].values

df['NO2_satellite_box'],_ = stats.boxcox(df['NO2_satellite'])
colors = np.where(df.COUNT > 300, 'r', 'b')
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box', c=colors)
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite', c=colors)

scaler=MinMaxScaler()
MEAN_NO2=df['MEAN_NO2'].values
MEAN_NO2=MEAN_NO2.reshape(-1,1)
MEAN_NO2=scaler.fit_transform(MEAN_NO2)


NO2_satellite=df['NO2_satellite'].values
NO2_satellite=NO2_satellite.reshape(-1,1)
NO2_satellite=scaler.fit_transform(NO2_satellite)



df['MEAN_NO2_T']= pd.DataFrame(MEAN_NO2)
df['NO2_satellite_T']= pd.DataFrame(NO2_satellite)

#df.corr()['MEAN_NO2_T'].sort_values().plot(kind='bar')

fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2,marker="o", ms = 10, mfc = 'r', linestyle='None',label='Ground Station')
plt.plot(NO2_satellite,marker="v", ms = 10,linestyle='None', mfc = 'w',label='Satellite')
plt.title('Correlation between Ground and Satellite for May 2018')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station')
plt.ylabel('Satellite')



corr=df.corr()['MEAN_NO2'].sort_values()

corr=list(corr)

grnd_corr_may=corr[2]

# %%
#Calculation for June 2018
df_june_2018= pd.read_csv('2018 June Grnd.csv')
df=df_june_2018

MEAN_NO2_june=df['MEAN_NO2'].values


df['NO2_satellite_box'],_ = stats.boxcox(df['NO2_satellite'])
#df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box')
#df.plot.scatter(x='MEAN_NO2',y='NO2_satellite')


scaler=MinMaxScaler()
MEAN_NO2=df['MEAN_NO2'].values
MEAN_NO2=MEAN_NO2.reshape(-1,1)
MEAN_NO2=scaler.fit_transform(MEAN_NO2)


NO2_satellite=df['NO2_satellite'].values
NO2_satellite=NO2_satellite.reshape(-1,1)
NO2_satellite=scaler.fit_transform(NO2_satellite)



df['MEAN_NO2_T']= pd.DataFrame(MEAN_NO2)
df['NO2_satellite_T']= pd.DataFrame(NO2_satellite)

#df.corr()['MEAN_NO2_T'].sort_values().plot(kind='bar')



fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2,marker="o", ms = 10, mfc = 'r',linestyle='None',label='Ground Station')
plt.plot(NO2_satellite,marker="v", ms = 10, mfc = 'w',linestyle='None',label='Satellite')
plt.title('Correlation between Ground and Satellite for June 2018')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station')
plt.ylabel('Satellite')

colors = np.where(df.COUNT > 300, 'r', 'b')
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box', c=colors)
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite', c=colors)

corr=df.corr()['MEAN_NO2'].sort_values()

corr=list(corr)

grnd_corr_june=corr[2]

# %%
#Calculation for July 2018

df_july_2018= pd.read_csv('2018 July Grnd.csv')
df=df_july_2018

MEAN_NO2_july=df['MEAN_NO2'].values

df['NO2_satellite_box'],_ = stats.boxcox(df['NO2_satellite'])
colors = np.where(df.COUNT > 300, 'r', 'b')
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box', c=colors)
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite', c=colors)


scaler=MinMaxScaler()
MEAN_NO2=df['MEAN_NO2'].values
MEAN_NO2=MEAN_NO2.reshape(-1,1)
MEAN_NO2=scaler.fit_transform(MEAN_NO2)


NO2_satellite=df['NO2_satellite'].values
NO2_satellite=NO2_satellite.reshape(-1,1)
NO2_satellite=scaler.fit_transform(NO2_satellite)



df['MEAN_NO2_T']= pd.DataFrame(MEAN_NO2)
df['NO2_satellite_T']= pd.DataFrame(NO2_satellite)

#df.corr()['MEAN_NO2_T'].sort_values().plot(kind='bar')

fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2,marker="o", ms = 10, mfc = 'r',linestyle='None',label='Ground Station')
plt.plot(NO2_satellite,marker="v", ms = 10, mfc = 'w',linestyle='None',label='Satellite')
plt.title('Correlation between Ground and Satellite for July 2018')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station')
plt.ylabel('Satellite')

corr=df.corr()['MEAN_NO2'].sort_values()

corr=list(corr)

grnd_corr_july=corr[3]

# %%
#Calculation for Aug 2018

df_Aug_2018= pd.read_csv('2018 Aug Grnd.csv')
df=df_Aug_2018

MEAN_NO2_aug=df['MEAN_NO2'].values

df['NO2_satellite_box'],_ = stats.boxcox(df['NO2_satellite'])
colors = np.where(df.COUNT > 300, 'r', 'b')
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box', c=colors)
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite', c=colors)


scaler=MinMaxScaler()
MEAN_NO2=df['MEAN_NO2'].values
MEAN_NO2=MEAN_NO2.reshape(-1,1)
MEAN_NO2=scaler.fit_transform(MEAN_NO2)


NO2_satellite=df['NO2_satellite'].values
NO2_satellite=NO2_satellite.reshape(-1,1)
NO2_satellite=scaler.fit_transform(NO2_satellite)



df['MEAN_NO2_T']= pd.DataFrame(MEAN_NO2)
df['NO2_satellite_T']= pd.DataFrame(NO2_satellite)

#df.corr()['MEAN_NO2_T'].sort_values().plot(kind='bar')

#df.plot.scatter(x='MEAN_NO2',y='NO2_satellite')

fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2,marker="o", ms = 10, mfc = 'r',linestyle='None',label='Ground Station')
plt.plot(NO2_satellite,marker="v", ms = 10, mfc = 'w',linestyle='None',label='Satellite')
plt.title('Correlation between Ground and Satellite for Aug 2018')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station')
plt.ylabel('Satellite')

corr=df.corr()['MEAN_NO2'].sort_values()

corr=list(corr)

grnd_corr_aug=corr[3]

# %%
#Calculation for Sep 2018

df_Sep_2018= pd.read_csv('2018 Sep Grnd.csv')
df=df_Sep_2018


MEAN_NO2_sep=df['MEAN_NO2'].values

df['NO2_satellite_box'],_ = stats.boxcox(df['NO2_satellite'])
colors = np.where(df.COUNT > 300, 'r', 'b')
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box', c=colors)
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite', c=colors)

scaler=MinMaxScaler()
MEAN_NO2=df['MEAN_NO2'].values
MEAN_NO2=MEAN_NO2.reshape(-1,1)
MEAN_NO2=scaler.fit_transform(MEAN_NO2)


NO2_satellite=df['NO2_satellite'].values
NO2_satellite=NO2_satellite.reshape(-1,1)
NO2_satellite=scaler.fit_transform(NO2_satellite)



df['MEAN_NO2_T']= pd.DataFrame(MEAN_NO2)
df['NO2_satellite_T']= pd.DataFrame(NO2_satellite)

#df.corr()['MEAN_NO2_T'].sort_values().plot(kind='bar')
#df.plot.scatter(x='MEAN_NO2',y='NO2_satellite')

fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2,marker="o", ms = 10, mfc = 'r',linestyle='None',label='Ground Station')
plt.plot(NO2_satellite,marker="v", ms = 10, mfc = 'w',linestyle='None',label='Satellite')
plt.title('Correlation between Ground and Satellite for Sep 2018')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station')
plt.ylabel('Satellite')

corr=df.corr()['MEAN_NO2'].sort_values()

corr=list(corr)

grnd_corr_sep=corr[2]

# %%
#Calculation for Oct 2018

df_oct_2018= pd.read_csv('2018 Oct Grnd.csv')
df=df_oct_2018

MEAN_NO2_oct=df['MEAN_NO2'].values

df['NO2_satellite_box'],_ = stats.boxcox(df['NO2_satellite'])
colors = np.where(df.COUNT > 300, 'r', 'b')
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box', c=colors)
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite', c=colors)


scaler=MinMaxScaler()
MEAN_NO2=df['MEAN_NO2'].values
MEAN_NO2=MEAN_NO2.reshape(-1,1)
MEAN_NO2=scaler.fit_transform(MEAN_NO2)


NO2_satellite=df['NO2_satellite'].values
NO2_satellite=NO2_satellite.reshape(-1,1)
NO2_satellite=scaler.fit_transform(NO2_satellite)



df['MEAN_NO2_T']= pd.DataFrame(MEAN_NO2)
df['NO2_satellite_T']= pd.DataFrame(NO2_satellite)

#df.corr()['MEAN_NO2_T'].sort_values().plot(kind='bar')

#df.plot.scatter(x='MEAN_NO2',y='NO2_satellite')
fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2,marker="o", ms = 10, mfc = 'r',linestyle='None',label='Ground Station')
plt.plot(NO2_satellite,marker="v", ms = 10, mfc = 'w',linestyle='None',label='Satellite')
plt.title('Correlation between Ground and Satellite for Oct 2018')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station')
plt.ylabel('Satellite')

corr=df.corr()['MEAN_NO2'].sort_values()

corr=list(corr)

grnd_corr_oct=corr[3]

# %%
#Calculation for Nov 2018

df_nov_2018= pd.read_csv('2018 Nov Grnd.csv')
df=df_nov_2018

MEAN_NO2_nov=df['MEAN_NO2'].values

df['NO2_satellite_box'],_ = stats.boxcox(df['NO2_satellite'])
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box')
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite')


scaler=MinMaxScaler()
MEAN_NO2=df['MEAN_NO2'].values
MEAN_NO2=MEAN_NO2.reshape(-1,1)
MEAN_NO2=scaler.fit_transform(MEAN_NO2)


NO2_satellite=df['NO2_satellite'].values
NO2_satellite=NO2_satellite.reshape(-1,1)
NO2_satellite=scaler.fit_transform(NO2_satellite)



df['MEAN_NO2_T']= pd.DataFrame(MEAN_NO2)
df['NO2_satellite_T']= pd.DataFrame(NO2_satellite)

#df.corr()['MEAN_NO2_T'].sort_values().plot(kind='bar')

#df.plot.scatter(x='MEAN_NO2',y='NO2_satellite')

fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2,marker="o", ms = 10, mfc = 'r',linestyle='None',label='Ground Station')
plt.plot(NO2_satellite,marker="v", ms = 10, mfc = 'w',linestyle='None',label='Satellite')
plt.title('Correlation between Ground and Satellite for Nov 2018')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station')
plt.ylabel('Satellite')

corr=df.corr()['MEAN_NO2'].sort_values()

corr=list(corr)

grnd_corr_nov=0
# Out:
# /Users/mdnhuda/opt/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:400: RuntimeWarning:
#
# All-NaN slice encountered
#
# /Users/mdnhuda/opt/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:401: RuntimeWarning:
#
# All-NaN slice encountered

# %%
#Calculation for Dec 2018

df_dec_2018= pd.read_csv('2018 Dec Grnd.csv')
df=df_dec_2018


MEAN_NO2_dec=df['MEAN_NO2'].values

df['NO2_satellite_box'],_ = stats.boxcox(df['NO2_satellite'])
colors = np.where(df.COUNT > 300, 'r', 'b')
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box', c=colors)
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite', c=colors)


scaler=MinMaxScaler()
MEAN_NO2=df['MEAN_NO2'].values
MEAN_NO2=MEAN_NO2.reshape(-1,1)
MEAN_NO2=scaler.fit_transform(MEAN_NO2)


NO2_satellite=df['NO2_satellite'].values
NO2_satellite=NO2_satellite.reshape(-1,1)
NO2_satellite=scaler.fit_transform(NO2_satellite)



#df['MEAN_NO2_T']= pd.DataFrame(MEAN_NO2)
#df['NO2_satellite_T']= pd.DataFrame(NO2_satellite)

#df.corr()['MEAN_NO2_T'].sort_values().plot(kind='bar')


#df.plot.scatter(x='MEAN_NO2',y='NO2_satellite')
fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2,marker="o", ms = 10, mfc = 'r',linestyle='None',label='Ground Station')
plt.plot(NO2_satellite,marker="v", ms = 10, mfc = 'w',linestyle='None',label='Satellite')
plt.title('Correlation between Ground and Satellite for Dec 2018')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station')
plt.ylabel('Satellite')

corr=df.corr()['MEAN_NO2'].sort_values()

corr=list(corr)

grnd_corr_dec=corr[2]

# %%
#Calculation for Jan 2019

df_jan_2018= pd.read_csv('2019 Jan Grnd.csv')
df=df_jan_2018


MEAN_NO2_jan_2019=df['MEAN_NO2'].values

df['NO2_satellite_box'],_ = stats.boxcox(df['NO2_satellite'])
colors = np.where(df.COUNT > 300, 'r', 'b')
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box', c=colors)
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite', c=colors)


scaler=MinMaxScaler()
MEAN_NO2=df['MEAN_NO2'].values
MEAN_NO2=MEAN_NO2.reshape(-1,1)
MEAN_NO2=scaler.fit_transform(MEAN_NO2)


NO2_satellite=df['NO2_satellite'].values
NO2_satellite=NO2_satellite.reshape(-1,1)
NO2_satellite=scaler.fit_transform(NO2_satellite)



#df['MEAN_NO2_T']= pd.DataFrame(MEAN_NO2)
#df['NO2_satellite_T']= pd.DataFrame(NO2_satellite)

#df.corr()['MEAN_NO2'].sort_values().plot(kind='bar')


#df.plot.scatter(x='MEAN_NO2',y='NO2_satellite')
fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2,marker="o", ms = 10, mfc = 'r',linestyle='None',label='Ground Station')
plt.plot(NO2_satellite,marker="v", ms = 10, mfc = 'w',linestyle='None',label='Satellite')
plt.title('Correlation between Ground and Satellite for Jan 2019')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station')
plt.ylabel('Satellite')

corr=df.corr()['MEAN_NO2'].sort_values()

corr=list(corr)

grnd_corr_jan_2019=corr[2]

# %%
#Calculation for Feb 2019

df_feb_2018= pd.read_csv('2019 Feb Grnd.csv')
df=df_feb_2018


MEAN_NO2_feb_2019=df['MEAN_NO2'].values

df['NO2_satellite_box'],_ = stats.boxcox(df['NO2_satellite'])
colors = np.where(df.COUNT > 300, 'r', 'b')
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box', c=colors)
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite', c=colors)


scaler=MinMaxScaler()
MEAN_NO2=df['MEAN_NO2'].values
MEAN_NO2=MEAN_NO2.reshape(-1,1)
MEAN_NO2=scaler.fit_transform(MEAN_NO2)


NO2_satellite=df['NO2_satellite'].values
NO2_satellite=NO2_satellite.reshape(-1,1)
NO2_satellite=scaler.fit_transform(NO2_satellite)



#df['MEAN_NO2_T']= pd.DataFrame(MEAN_NO2)
#df['NO2_satellite_T']= pd.DataFrame(NO2_satellite)

#df.corr()['MEAN_NO2'].sort_values().plot(kind='bar')


#df.plot.scatter(x='MEAN_NO2',y='NO2_satellite')
fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2,marker="o", ms = 10, mfc = 'r',linestyle='None',label='Ground Station')
plt.plot(NO2_satellite,marker="v", ms = 10, mfc = 'w',linestyle='None',label='Satellite')
plt.title('Correlation between Ground and Satellite for Feb 2019')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station')
plt.ylabel('Satellite')

corr=df.corr()['MEAN_NO2'].sort_values()

corr=list(corr)

grnd_corr_feb_2019=corr[3]

# %%
#Calculation for March 2019

df_march_2018= pd.read_csv('2019 Feb Grnd.csv')
df=df_march_2018


MEAN_NO2_march_2019=df['MEAN_NO2'].values

df['NO2_satellite_box'],_ = stats.boxcox(df['NO2_satellite'])
colors = np.where(df.COUNT > 300, 'r', 'b')
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box', c=colors)
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite', c=colors)


scaler=MinMaxScaler()
MEAN_NO2=df['MEAN_NO2'].values
MEAN_NO2=MEAN_NO2.reshape(-1,1)
MEAN_NO2=scaler.fit_transform(MEAN_NO2)


NO2_satellite=df['NO2_satellite'].values
NO2_satellite=NO2_satellite.reshape(-1,1)
NO2_satellite=scaler.fit_transform(NO2_satellite)



#df['MEAN_NO2_T']= pd.DataFrame(MEAN_NO2)
#df['NO2_satellite_T']= pd.DataFrame(NO2_satellite)

#df.corr()['MEAN_NO2'].sort_values().plot(kind='bar')


#df.plot.scatter(x='MEAN_NO2',y='NO2_satellite')
fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2,marker="o", ms = 10, mfc = 'r',linestyle='None',label='Ground Station')
plt.plot(NO2_satellite,marker="v", ms = 10, mfc = 'w',linestyle='None',label='Satellite')
plt.title('Correlation between Ground and Satellite for March 2019')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station')
plt.ylabel('Satellite')

corr=df.corr()['MEAN_NO2'].sort_values()

corr=list(corr)

grnd_corr_march_2019=corr[3]

# %%
#Calculation for April 2019

df_april_2018= pd.read_csv('2019 April Grnd.csv')
df=df_april_2018


MEAN_NO2_march_2019=df['MEAN_NO2'].values

df['NO2_satellite_box'],_ = stats.boxcox(df['NO2_satellite'])
colors = np.where(df.COUNT > 300, 'r', 'b')
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box', c=colors)
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite', c=colors)


scaler=MinMaxScaler()
MEAN_NO2=df['MEAN_NO2'].values
MEAN_NO2=MEAN_NO2.reshape(-1,1)
MEAN_NO2=scaler.fit_transform(MEAN_NO2)


NO2_satellite=df['NO2_satellite'].values
NO2_satellite=NO2_satellite.reshape(-1,1)
NO2_satellite=scaler.fit_transform(NO2_satellite)



#df['MEAN_NO2_T']= pd.DataFrame(MEAN_NO2)
#df['NO2_satellite_T']= pd.DataFrame(NO2_satellite)

#df.corr()['MEAN_NO2'].sort_values().plot(kind='bar')


#df.plot.scatter(x='MEAN_NO2',y='NO2_satellite')
fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2,marker="o", ms = 10, mfc = 'r',linestyle='None',label='Ground Station')
plt.plot(NO2_satellite,marker="v", ms = 10, mfc = 'w',linestyle='None',label='Satellite')
plt.title('Correlation between Ground and Satellite for April 2019')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station')
plt.ylabel('Satellite')

corr=df.corr()['MEAN_NO2'].sort_values()

corr=list(corr)

grnd_corr_april_2019=corr[3]

# %%
#Calculation for May 2019

df_may_2018= pd.read_csv('2019 May Grnd.csv')
df=df_may_2018


MEAN_NO2_march_2019=df['MEAN_NO2'].values

df['NO2_satellite_box'],_ = stats.boxcox(df['NO2_satellite'])
colors = np.where(df.COUNT > 300, 'r', 'b')
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box', c=colors)
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite', c=colors)


scaler=MinMaxScaler()
MEAN_NO2=df['MEAN_NO2'].values
MEAN_NO2=MEAN_NO2.reshape(-1,1)
MEAN_NO2=scaler.fit_transform(MEAN_NO2)


NO2_satellite=df['NO2_satellite'].values
NO2_satellite=NO2_satellite.reshape(-1,1)
NO2_satellite=scaler.fit_transform(NO2_satellite)



#df['MEAN_NO2_T']= pd.DataFrame(MEAN_NO2)
#df['NO2_satellite_T']= pd.DataFrame(NO2_satellite)

#df.corr()['MEAN_NO2'].sort_values().plot(kind='bar')


#df.plot.scatter(x='MEAN_NO2',y='NO2_satellite')
fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2,marker="o", ms = 10, mfc = 'r',linestyle='None',label='Ground Station')
plt.plot(NO2_satellite,marker="v", ms = 10, mfc = 'w',linestyle='None',label='Satellite')
plt.title('Correlation between Ground and Satellite for May 2019')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station')
plt.ylabel('Satellite')

corr=df.corr()['MEAN_NO2'].sort_values()

corr=list(corr)

grnd_corr_may_2019=corr[3]

# %%
#Calculation for June 2019

df_june_2018= pd.read_csv('2019 June Grnd.csv')
df=df_june_2018


MEAN_NO2_march_2019=df['MEAN_NO2'].values

df['NO2_satellite_box'],_ = stats.boxcox(df['NO2_satellite'])
colors = np.where(df.COUNT > 300, 'r', 'b')
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite_box', c=colors)
df.plot.scatter(x='MEAN_NO2',y='NO2_satellite', c=colors)


scaler=MinMaxScaler()
MEAN_NO2=df['MEAN_NO2'].values
MEAN_NO2=MEAN_NO2.reshape(-1,1)
MEAN_NO2=scaler.fit_transform(MEAN_NO2)


NO2_satellite=df['NO2_satellite'].values
NO2_satellite=NO2_satellite.reshape(-1,1)
NO2_satellite=scaler.fit_transform(NO2_satellite)



#df['MEAN_NO2_T']= pd.DataFrame(MEAN_NO2)
#df['NO2_satellite_T']= pd.DataFrame(NO2_satellite)

#df.corr()['MEAN_NO2'].sort_values().plot(kind='bar')


#df.plot.scatter(x='MEAN_NO2',y='NO2_satellite')
fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2,marker="o", ms = 10, mfc = 'r',linestyle='None',label='Ground Station')
plt.plot(NO2_satellite,marker="v", ms = 10, mfc = 'w',linestyle='None',label='Satellite')
plt.title('Correlation between Ground and Satellite for June 2019')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station')
plt.ylabel('Satellite')

corr=df.corr()['MEAN_NO2'].sort_values()

corr=list(corr)

grnd_corr_june_2019=corr[4]

# %%
correlation=[grnd_corr_may,grnd_corr_june,grnd_corr_july,grnd_corr_aug,
             grnd_corr_sep,grnd_corr_oct,grnd_corr_nov,grnd_corr_dec,grnd_corr_jan_2019,
             grnd_corr_feb_2019,grnd_corr_march_2019,grnd_corr_april_2019,grnd_corr_may_2019,grnd_corr_june_2019]

# %%
plt.plot(correlation,marker="o", ms = 20,linestyle='None', mfc = 'r')
plt.title('Correlation between Ground and Satellite For Whole Month till Dec')
plt.ylabel('Coorelation For Whole Month')
# Out:
# Text(0, 0.5, 'Coorelation For Whole Month')

# %%
df=pd.read_csv('Correlation NO2 Week.csv')
Corr_Grnd_Sat=df['Ground Mean NO2 and Satellite  NO2 Correlation']

# %%
plt.plot(Corr_Grnd_Sat,marker="o", ms = 20, linestyle='None',mfc = 'r')
plt.title('Correlation between Ground and Satellite For Week Till May 2019')
plt.ylabel('Coorelation For Week')
# Out:
# Text(0, 0.5, 'Coorelation For Week')

# %%
fig = plt.figure(figsize=(14,6))
plt.plot(MEAN_NO2_may,marker=4, ms = 10, mfc = 'r',linestyle='None', label='may')
plt.plot(MEAN_NO2_june,marker=5, ms = 10, mfc = 'r',linestyle='None',label='june')
plt.plot(MEAN_NO2_july,marker=6, ms = 10, mfc = 'r',linestyle='None',label='july')
plt.plot(MEAN_NO2_aug,marker=7, ms = 10, mfc = 'r',linestyle='None',label='aug')
#plt.plot(MEAN_NO2_sep,marker=4, ms = 10, mfc = 'r',label='sep')
#plt.plot(MEAN_NO2_oct,marker=5, ms = 10, mfc = 'r',label='oct')
#plt.plot(MEAN_NO2_nov,marker=6, ms = 10, mfc = 'r',label='nov')
#plt.plot(MEAN_NO2_dec,marker=7, ms = 10, mfc = 'r',label='dec')
plt.title('Ground Station  NO2 Data for Different month')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station Data')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %%
fig = plt.figure(figsize=(14,6))
#plt.plot(MEAN_NO2_may,marker=0, ms = 10, mfc = 'r',label='may')
#plt.plot(MEAN_NO2_june,marker=1, ms = 10, mfc = 'r',label='june')
#plt.plot(MEAN_NO2_july,marker=2, ms = 10, mfc = 'r',label='july')
#plt.plot(MEAN_NO2_aug,marker=3, ms = 10, mfc = 'r',label='aug')
plt.plot(MEAN_NO2_sep,marker=4, ms = 10, mfc = 'r',linestyle='None',label='sep')
plt.plot(MEAN_NO2_oct,marker=5, ms = 10, mfc = 'r',linestyle='None',label='oct')
plt.plot(MEAN_NO2_nov,marker=6, ms = 10, mfc = 'r',linestyle='None',label='nov')
plt.plot(MEAN_NO2_dec,marker=7, ms = 10, mfc = 'r',linestyle='None',label='dec')
plt.title('Ground Station  NO2 Data for Different month')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('Ground Station Data')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %%
no2_may = xr.open_dataset("CAMS_2018_May_12.00_Surface.nc", engine="netcdf4")
no2_june = xr.open_dataset("CAMS_2018_June_12.00_Surface.nc", engine="netcdf4")
no2_july = xr.open_dataset("CAMS_2018_July_12.00_Surface.nc", engine="netcdf4")
no2_aug = xr.open_dataset("CAMS_2018_Aug_12.00_Surface.nc", engine="netcdf4")
no2_sep = xr.open_dataset("CAMS_2018_Sep_12.00_Surface.nc", engine="netcdf4")
no2_oct = xr.open_dataset("CAMS_2018_Oct_12.00_Surface.nc", engine="netcdf4")
no2_nov = xr.open_dataset("CAMS_2018_Nov_12.00_Surface.nc", engine="netcdf4")
no2_dec = xr.open_dataset("CAMS_2018_Dec_12.00_Surface.nc", engine="netcdf4")

# %%
tno2_may=no2_may.tcno2
tno2_june=no2_june.tcno2
tno2_july=no2_july.tcno2
tno2_aug=no2_aug.tcno2
tno2_sep=no2_sep.tcno2
tno2_oct=no2_oct.tcno2
tno2_nov=no2_nov.tcno2
tno2_dec=no2_dec.tcno2


bay_area_may= tno2_may.sel(latitude=36, longitude=120)
bay_area_june= tno2_june.sel(latitude=36, longitude=120)
bay_area_july= tno2_july.sel(latitude=36, longitude=120)
bay_area_aug= tno2_aug.sel(latitude=36, longitude=120)
bay_area_sep= tno2_sep.sel(latitude=36, longitude=120)
bay_area_oct= tno2_oct.sel(latitude=36, longitude=120)
bay_area_nov= tno2_nov.sel(latitude=36, longitude=120)
bay_area_dec= tno2_dec.sel(latitude=36, longitude=120)

# %%
fig = plt.figure(figsize=(14,6))
plt.plot(bay_area_may,marker=4, ms = 10, mfc = 'r',linestyle='None',label='may')
plt.plot(bay_area_june,marker=5, ms = 10, mfc = 'r',linestyle='None',label='june')
plt.plot(bay_area_july,marker=6, ms = 10, mfc = 'r',linestyle='None',label='july')
plt.plot(bay_area_aug,marker=7, ms = 10, mfc = 'r',linestyle='None',label='aug')
plt.title('CAMs NO2 Data for Different month')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('CAMs NO2 Data')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %%
fig = plt.figure(figsize=(14,6))
plt.plot(bay_area_sep,marker=4, ms = 10, mfc = 'r',linestyle='None',label='sep')
plt.plot(bay_area_oct,marker=5, ms = 10, mfc = 'r',linestyle='None',label='oct')
plt.plot(bay_area_nov,marker=6, ms = 10, mfc = 'r',linestyle='None',label='nov')
plt.plot(bay_area_dec,marker=7, ms = 10, mfc = 'r',linestyle='None',label='dec')
plt.title('CAMs NO2 Data for Different month')
plt.legend(loc='best',prop={'size':14})
plt.xlabel('CAMs NO2 Data')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')
