# %%
import os
import geemap
import pyproj
from pyproj import CRS

# %%
dem = os.path.join('landsat.tif')

# %%
dem
# Out:
# 'landsat.tif'

# %%
# Map = geemap.Map()
# Map

# Map.add_raster(dem, colormap='terrain', layer_name='DEM')

# %%
import rasterio
from rasterio import plot

# %%
dem = rasterio.open('landsat-0000000000-0000023296.tif')

# %%
plot.show(dem)
